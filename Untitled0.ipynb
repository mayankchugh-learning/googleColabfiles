# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the parameters
Vs = 10 # Source voltage in volts
R = 1000 # Resistance in ohms
C1 = 0.001 # Capacitance of the first capacitor in farads
C2 = 0.01 # Capacitance of the second capacitor in farads
t = np.linspace(0, 0.1, 1000) # Time in seconds

# Calculate the voltage across the capacitors while discharging
Vc1 = Vs * np.exp(-t / (R * C1)) # Voltage of the first capacitor in volts
Vc2 = Vs * np.exp(-t / (R * C2)) # Voltage of the second capacitor in volts

# Plot the results
plt.plot(t, Vc1, label = 'C1 = 0.001 F')
plt.plot(t, Vc2, label = 'C2 = 0.01 F')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Discharge of two capacitors with different capacitances')
plt.legend()
plt.grid()
plt.show()

# %%
# Define the parameters
Vs = 10 # Source voltage in volts
R = 1000 # Resistance in ohms
C1 = 0.001 # Capacitance of the first capacitor in farads
C2 = 0.01 # Capacitance of the second capacitor in farads
t = np.linspace(0, 0.1, 1000) # Time in seconds

# %%
plt.grid()
plt.show()

# %%
plt.plot(t, Vc1, label = 'C1 = 0.001 F')
plt.plot(t, Vc2, label = 'C2 = 0.01 F')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Discharge of two capacitors with different capacitances')
plt.legend()
plt.grid()
plt.show()
