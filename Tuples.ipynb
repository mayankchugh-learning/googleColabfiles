# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (1,2,3,4,45,45.45 , 45+7j , "subh" , True)

# %%
type(t1)
# Out:
# tuple

# %%
l = [1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
t1
# Out:
# (1, 2, 3, 4, 45, 45.45, (45+7j), 'subh', True)

# %%
t1[0]
# Out:
# 1

# %%
t1[7]
# Out:
# 'subh'

# %%
t1[::-1]
# Out:
# (True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1 = t1[::-1]

# %%
t1
# Out:
# (True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1[0:3]
# Out:
# (True, 'subh', (45+7j))

# %%
t1.count(4)
# Out:
# 1

# %%
t1.count("abc")
# Out:
# 0

# %%
t1.index(1)
# Out:
# 0

# %%
t1.index(2)
# Out:
# 7

# %%
t1.index('subh')
# Out:
# 1

# %%
t1.index(True)
# Out:
# 0

# %%
t1.count(True)
# Out:
# 2

# %%
t1.count(1)
# Out:
# 2

# %%
t1
# Out:
# (True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
t1[0]
# Out:
# True

# %%
t1[0] = 345
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f5a7769252f6> in <cell line: 1>()
# ----> 1 t1[0] = 345
#
# TypeError: 'tuple' object does not support item assignment

# %%
l[0]
# Out:
# 1

# %%
l[0] = 100

# %%
l
# Out:
# [100, 2, 3, 4]

# %%
for i in t1:
  print(i, type(i))
# Out:
# True <class 'bool'>
# subh <class 'str'>
# (45+7j) <class 'complex'>
# 45.45 <class 'float'>
# 45 <class 'int'>
# 4 <class 'int'>
# 3 <class 'int'>
# 2 <class 'int'>
# 1 <class 'int'>

# %%
for i in t1:
  print(i, type[i])
# Out:
# True type[True]
# subh type['subh']
# (45+7j) type[(45+7j)]
# 45.45 type[45.45]
# 45 type[45]
# 4 type[4]
# 3 type[3]
# 2 type[2]
# 1 type[1]

# %%
t2 = (1,2,3,4,4)

# %%
t2
# Out:
# (1, 2, 3, 4, 4)

# %%
t2 * 3
# Out:
# (1, 2, 3, 4, 4, 1, 2, 3, 4, 4, 1, 2, 3, 4, 4)

# %%
max(t2)
# Out:
# 4

# %%
min(t2)
# Out:
# 1

# %%
t3 = (t1,t2)

# %%
t3
# Out:
# ((True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1), (1, 2, 3, 4, 4))

# %%
#t4 = (t1,l,t3)

# %%
#t4

# %%
l[2] = 200

# %%
l
# Out:
# [100, 2, 200, 4]

# %%
l = l.insert(2,30)

# %%
print(l)
# Out:
# None

# %%
type(l)
# Out:
# NoneType

# %%
t4 = (t1,l1,t3)

# %%
t4
# Out:
# ((True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1),
#  [1, 200, 700, 200, 6, 4, 5],
#  ((True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1), (1, 2, 3, 4, 4)))

# %%
del t4

# %%
t4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-7e8198522aa2> in <cell line: 1>()
# ----> 1 t4
#
# NameError: name 't4' is not defined

# %%
t1
# Out:
# (True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
len(t1)
# Out:
# 9

# %%
t1
# Out:
# (True, 'subh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
"sudb" in t1
# Out:
# False

# %%
1 in t1
# Out:
# True

# %%
my_list = [1, 2, 3]
my_list.insert(2, 4) # my_list.insert(index, element)
print(my_list)  # Output: [1, 2, 4, 3]
# Out:
# [1, 2, 4, 3]

# %%
my_list.append(6)
my_list
# Out:
# [1, 2, 4, 3, 6, 6, 6]

# %%
fruits = []
fruits.append("apple")
fruits.append("banana")
fruits.append("cherry")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append(4)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 4]

# %%
l1 = [1,2,3,4]

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
type(l1)
# Out:
# list

# %%
l1[2] = 200

# %%
l1
# Out:
# [1, 2, 200, 4]

# %%
type(l1)
# Out:
# list

# %%
l1.append(5)

# %%
l1
# Out:
# [1, 2, 200, 4, 5]

# %%
type(l1)
# Out:
# list

# %%
l1.insert(3,6)

# %%
l1
# Out:
# [1, 2, 200, 6, 4, 5]

# %%
type(l1)
# Out:
# list

# %%
t5 = (t1,l1)

# %%
type(l1)
# Out:
# list

# %%
l1.insert(1,200)

# %%
l1
# Out:
# [1, 200, 2, 200, 6, 4, 5]

# %%
type(l1)
# Out:
# list

# %%
l1[2] = 700

# %%
type(l1)
# Out:
# list

# %%
l1
# Out:
# [1, 200, 700, 200, 6, 4, 5]
