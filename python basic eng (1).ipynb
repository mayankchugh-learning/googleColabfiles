# %%
print("hello to a progamming world")
# Out:
# hello to a progamming world

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 34.4565

# %%
b
# Out:
# 34.4565

# %%
type(b)
# Out:
# float

# %%
c = "sudh"

# %%
c1 = 'pwskills'

# %%
type(c)
# Out:
# str

# %%
d= True

# %%
type(d)
# Out:
# bool

# %%
d1 = False

# %%
type(d1)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-f8487d9d0863> in <cell line: 1>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
False / True
# Out:
# 0.0

# %%
e = 4+7j

# %%
e = 4+7A
# Out:
#   File "<ipython-input-22-8505101e2d36>", line 1
#     e = 4+7A
#           ^
# SyntaxError: invalid decimal literal

# %%
type(e)
# Out:
# complex

# %%
e
# Out:
# (4+7j)

# %%
e.real
# Out:
# 4.0

# %%
"""This is extracting a
imag part of
my complex number"""
e.imag
# Out:
# 7.0

# %%
a= 10

# %%
1a = 10
# Out:
#   File "<ipython-input-28-1be9f8edb7cd>", line 1
#     1a = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
11 = 10
# Out:
#   File "<ipython-input-29-bb9039d96a78>", line 1
#     11 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
@ererw = 34
# Out:
#   File "<ipython-input-30-baaa00d15e51>", line 1
#     @ererw = 34
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#fdsf = 345

# %%
# %fdsfa= 3434
# Out:
# UsageError: Line magic function `%fdsfa=` not found.

# %%
_a = 34

# %%
_a
# Out:
# 34

# %%
a1 = 4554

# %%
a& = 45
# Out:
#   File "<ipython-input-36-51a91f96c727>", line 1
#     a& = 45
#        ^
# SyntaxError: invalid syntax

# %%
a% = 234
# Out:
#   File "<ipython-input-37-12db2ce45d9a>", line 1
#     a% = 234
#        ^
# SyntaxError: invalid syntax

# %%
sudh = 345

# %%
sudh
# Out:
# 345

# %%
s = "sudh"

# %%
a = 10

# %%
str(a)+s
# Out:
# '10sudh'

# %%
b = input()
# Out:
# Hi

# %%
b
# Out:
# 'Hi'

# %%
type(b)
# Out:
# str

# %%
c = int(input())
# Out:
# 12

# %%
type(c)
# Out:
# int

# %%
def test():
  a ={ 1,4,5,"pw","akash"}
  print(a)

# %%
test()
# Out:
# {1, 4, 5, 'akash', 'pw'}

# %%
l = (2,4,6,7,9,8)

# %%
def test4(a):
  n = []
  for i in a:
    if type(i) == int or type(i) == float:
      n.append(i)
  return n

# %%
test4(l)
# Out:
# [2, 4, 6, 7, 9, 8]

# %%
a = [1,2,3,4,5,6,7,"hello", "world"]

# %%
def test(a):
    n = []
    for i in a:
        if type(i) == int:
            n.append(i)
    return n

# %%
test(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))
# Out:
# 22

# %%
calc = lambda num: "Even number" if num % 2 == 0 else "Odd number"

print(calc(20))
# Out:
# Even number

# %%
filter_nums = lambda s: ''.join([ch for ch in s if ch.isdigit()])
print("filter_nums():", filter_nums("Geeks101"))

do_exclaim = lambda s: s + '!'
print("do_exclaim():", do_exclaim("I am tired"))

find_sum = lambda n: sum([int(x) for x in str(n)])
print("find_sum():", find_sum(1200))
# Out:
# filter_nums(): 101
# do_exclaim(): I am tired!
# find_sum(): 3

# %%
l = ["1", "2", "9", "0", "-1", "-2"]
sorted(l,key=lambda x:int(x))
# Out:
# ['-2', '-1', '0', '1', '2', '9']

# %%
l = [2,3,5,4,7,6]
print(list(map(lambda x : x**2 , l)))
# Out:
# [4, 9, 25, 16, 49, 36]

# %%
l = [2,3,5,4,7,6]

# %%
list(map(lambda x : x**2, l))
# Out:
# [4, 9, 25, 16, 49, 36]

# %%
l1 =[2,4,6,8]
l2 =[1,3,5,7]
l=[]
for i in range(len(l1)):
  l.append(l1[i]+l2[i])

print(l)
# Out:
# [3, 7, 11, 15]

# %%
l = [2,4,6,4,8]

def sum(l):
  total=1
  for i in l:
    total *= i
  return total

# %%
sum(l)
# Out:
# 1536

# %%
str_name = "1234abcd"
print(str_name[::-1])
# Out:
# dcba4321

# %%
str_name = "1234abcd"

# %%
def revers_fun(str_name):
  rev_str =''
  index = len(str_name)
  while index > 0:
    rev_str += str_name[index-1]
    index -= 1
  return rev_str

# %%
revers_fun(str_name)
# Out:
# 'dcba4321'

# %%
def unique_list(l):
  x = []
  for a in l:
    if a not in x:
      x.append(a)
  return x

print(unique_list([1,2,3,3,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
def perfact_num(l):
  x=0
  for i in range(1,l):
    if l%i==0:
      x+=i
  return x==l
print(perfact_num(6))
# Out:
# True
