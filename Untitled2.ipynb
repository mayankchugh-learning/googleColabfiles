# %%
sentence = "your input sentence here"
word_list = sentence.split()
unique_words = list(set(word_list))
clean_sentence = ' '.join(unique_words)
print(clean_sentence)
# Out:
# your here sentence input
